# %%
# Step 1: Import the Hugging Face Transformers library
from transformers import AutoTokenizer, AutoModelForCausalLM

# Step 2: Pick a sample LLM
model_id = "facebook/opt-125m"

# Step 3: Load a tokenizer and a model
if "model" not in globals() or model is None:
    print(f"[loader] Loading {model_id} model.")

    tokenizer = AutoTokenizer.from_pretrained(model_id)
    model = AutoModelForCausalLM.from_pretrained(model_id)
else:
    print(f"[loader] Reusing {model_id} model that's already in RAM.")

# Step 4: Set up a sample prompt
prompt = "Here's a simple way to make delicious pasta:"

# Step 5: Tokenize the input prompt – convert it into token IDs the model can process
inputs = tokenizer(prompt, return_tensors="pt")

# Step 6: Generate text with the chosen settings.
# - do_sample=True enables *probabilistic sampling* (randomness). Without this, the model tends to
#   pick the most likely token each time (greedy decoding), which can be dull/repetitive.
# - temperature/top_k/top_p only affect results when sampling is enabled.
# - num_return_sequences allows to generate N outputs. When sampling is disabled, can only be set to 1.
outputs = model.generate(
    **inputs,
    do_sample=False,
    temperature=0.7,
    top_k=50,
    top_p=0.6,
    max_new_tokens=80,
    num_return_sequences=1,
)

for i, output in enumerate(outputs):
    decoded_text = tokenizer.decode(output, skip_special_tokens=True)
    print(f"Generated output {i + 1} says:\n{decoded_text}\n{'-'*60}")
# Out:
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# [loader] Reusing facebook/opt-125m model that's already in RAM.
# Generated output 1 says:
# Here's a simple way to make delicious pasta:
#
# 1. Preheat the oven to 350 degrees.
#
# 2. In a large bowl, combine the flour, salt, and pepper.
#
# 3. In a large bowl, combine the eggs, sugar, and salt.
#
# 4. In a large bowl, combine the flour, salt, and pepper.
#
# 5. In a large bowl, combine the eggs, sugar
# ------------------------------------------------------------
