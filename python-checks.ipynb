# %%
# !python -c "import sys; print(sys.executable)"
# Out:
# /opt/conda/bin/python

# %%
# !which python
# Out:
# /opt/conda/bin/python

# %%
# !python --version
# Out:
# Python 3.13.11

# %%
print("Success!")
# Out:
# Success!
